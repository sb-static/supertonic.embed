# %%
# !git clone https://github.com/sb-static/supertonic.embed
# Out:
# Cloning into 'supertonic.embed'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 61 (delta 22), reused 39 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (61/61), 1.37 MiB | 19.42 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
# %cd /content/supertonic.embed
# !pip install -r requirements.txt
# Out:
# /content/supertonic.embed
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 106.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 41.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.4/238.4 kB 27.3 MB/s eta 0:00:00
# ...

# %%
# !git clone https://huggingface.co/Supertone/supertonic-3/
# Out:
# Cloning into 'supertonic-3'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 32 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 1.21 MiB | 4.29 MiB/s, done.
# Filtering content: 100% (9/9), 381.75 MiB | 115.11 MiB/s, done.

# %%
# !mv /content/supertonic.embed/supertonic-3/onnx/ /content/supertonic.embed/
# !mv /content/supertonic.embed/supertonic-3/voice_styles/ /content/supertonic.embed/

# %%
# %%writefile /content/supertonic.embed/configs/vedenina.json
# {
#     "name": "vedenina",
#     "target_wav": "/content/supertonic.embed/wavs/Avatar_Intro_10s.wav",
#     "reference_style": "auto",
#     "seed": 42,
#     "lr": 2e-4,
#     "num_steps": 3000,
#     "total_step": 5,
#     "speed": 1.05,
#     "save_every": 500
# }
# Out:
# Writing /content/supertonic.embed/configs/vedenina.json

# %%
# !python optimize_style.py vedenina
# Out:
# Loading config: configs/vedenina.json
# Using device: cuda
# Name: vedenina
#
# Loading target WAV: /content/supertonic.embed/wavs/Avatar_Intro_10s.wav
#   Duration: 10.07s
#
# Loading WavLM-Large...
# config.json: 2.22kB [00:00, 3.09MB/s]
# ...
# pytorch_model.bin: 100% 1.26G/1.26G [00:14<00:00, 88.7MB/s]
# Loading weights:  95% 464/488 [00:00<00:00, 751.15it/s, Materializing param=feature_extractor.conv_layers.0.layer_norm.bias]
# Loading weights: 100% 488/488 [00:00<00:00, 803.82it/s, Materializing param=masked_spec_embed]
#
# model.safetensors:   0% 0.00/1.26G [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/1.26G [00:00<?, ?B/s]  WavLM loaded.
# Extracting target features (Layer 3)...
#
# model.safetensors:   0% 0.00/1.26G [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/1.26G [00:00<?, ?B/s]
# model.safetensors:   5% 67.1M/1.26G [00:01<00:03, 330MB/s]
# model.safetensors:  11% 134M/1.26G [00:01<00:03, 329MB/s]
# model.safetensors:  15% 185M/1.26G [00:01<00:03, 300MB/s]
# ...
